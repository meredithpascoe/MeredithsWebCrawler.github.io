# %%
# Import Requests library 
import requests
# Download webpage using requests.get
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=42.2408&lon=-83.6131#.YmF-q9PMKUk")
# Import BeautifulSoup library and create a class to parse the webpage
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# Capture all the extended forecast items 
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")

# %%
# Find all the time period names used in the seven day forecast
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods

# %%
# Find the weather conditions summary, temperature, and and conditions description for the various time periods in the seven day forecast
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]
print(short_descs)
print(temps)
print(descs)
# Out:
# ['DecreasingClouds', 'Mostly Clear', 'Mostly SunnythenScatteredShowers', 'ScatteredShowers', 'ScatteredShowers thenMostly Sunny', 'Partly Cloudy', 'Mostly SunnythenScatteredShowers andBreezy', 'ShowersLikely', 'ShowersLikely']
# ['High: 67 °F', 'Low: 40 °F', 'High: 58 °F', 'Low: 46 °F', 'High: 80 °F', 'Low: 61 °F', 'High: 80 °F', 'Low: 53 °F', 'High: 62 °F']
# ['This Afternoon: Mostly cloudy, then gradually becoming sunny, with a high near 67. West wind around 17 mph, with gusts as high as 30 mph. ', 'Tonight: Mostly clear, with a low around 40. West wind 6 to 11 mph becoming light northwest  after midnight. Winds could gust as high as 20 mph. ', 'Friday: Scattered showers after 3pm.  Partly sunny, with a high near 58. East southeast wind 6 to 10 mph.  Chance of precipitation is 30%.', 'Friday Night: Scattered showers.  Cloudy, with a low around 46. East wind around 10 mph, with gusts as high as 18 mph.  Chance of precipitation is 50%.', 'Saturday: Scattered showers before 9am.  Mostly cloudy, then gradually becoming sunny, with a high near 80. Southeast wind 8 to 13 mph becoming south southwest in the afternoon. Winds could gust as high as 22 mph.  Chance of precipitation is 40%.', 'Saturday Night: Partly cloudy, with a low around 61.', 'Sunday: Scattered showers after 3pm.  Mostly sunny, with a high near 80. Breezy.  Chance of precipitation is 40%.', 'Sunday Night: Showers likely, mainly after 9pm.  Mostly cloudy, with a low around 53.', 'Monday: Showers likely, mainly before 9am.  Mostly cloudy, with a high near 62.']

# %%
# Import Pandas library
import pandas as pd
#Add data to a Pandas DataFrame
weather = pd.DataFrame({
    "period": periods,
    "short_desc": short_descs,
    "temp": temps,
    "desc":descs
})
weather
# Out:
#           period                                  short_desc         temp  \
# 0  ThisAfternoon                            DecreasingClouds  High: 67 °F
# 1        Tonight                                Mostly Clear   Low: 40 °F
# 2         Friday            Mostly SunnythenScatteredShowers  High: 58 °F
# 3    FridayNight                            ScatteredShowers   Low: 46 °F
# 4       Saturday           ScatteredShowers thenMostly Sunny  High: 80 °F
# 5  SaturdayNight                               Partly Cloudy   Low: 61 °F
# 6         Sunday  Mostly SunnythenScatteredShowers andBreezy  High: 80 °F
# 7    SundayNight                               ShowersLikely   Low: 53 °F
# 8         Monday                               ShowersLikely  High: 62 °F
#
#                                                 desc
# 0  This Afternoon: Mostly cloudy, then gradually ...
# 1  Tonight: Mostly clear, with a low around 40. W...
# 2  Friday: Scattered showers after 3pm.  Partly s...
# 3  Friday Night: Scattered showers.  Cloudy, with...
# 4  Saturday: Scattered showers before 9am.  Mostl...
# 5  Saturday Night: Partly cloudy, with a low arou...
# 6  Sunday: Scattered showers after 3pm.  Mostly s...
# 7  Sunday Night: Showers likely, mainly after 9pm...
# 8  Monday: Showers likely, mainly before 9am.  Mo...

# %%
# Create data on to Google Drive
from google.colab import drive
# Mount your Drive to the Colab VM.
#drive._mount('/gdrive')
drive.mount('/gdrive')

# the file path where to store the output csv on google drive
output_file = '/gdrive/My Drive/weather.csv'

# Save the dataframe as a csv file
weather.to_csv(output_file, index=False)
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
from google.colab import files
files.download(output_file)
print("the csv has been downloaded to your local computer. The program has been completed successfully")
# Out:
# the csv has been downloaded to your local computer. The program has been completed successfully
